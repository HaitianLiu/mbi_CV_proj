# %% [markdown]
# <a href="https://colab.research.google.com/github/HaitianLiu/mbi_CV_proj/blob/main/No_aug_cv_final_proj.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing the necessary libraries
import os
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime
from tensorflow import keras
from tensorflow.keras.datasets import mnist
from tensorflow.keras import layers
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, AveragePooling2D, GlobalAvgPool2D, Dense, Add, Flatten, Dropout, concatenate
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.activations import relu
from tensorflow.keras import Input
from tensorflow.keras.models import Model
from IPython.display import Image, display

# shush warnings
import logging
import tensorflow as tf

# Set logging level to only show errors
logging.getLogger("tensorflow").setLevel(logging.ERROR)

# Filter out warnings related to while_loop conversions
tf.get_logger().setLevel("ERROR")

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from matplotlib.colors import Colormap
import seaborn as sns
import os

import numpy as np
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from PIL import Image, ImageEnhance

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
import tensorflow_datasets as tfds
from tensorflow.keras import layers
from keras import utils

import zipfile
import scipy.io

from tensorflow import keras
from keras.callbacks import EarlyStopping, LambdaCallback, ModelCheckpoint
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.applications import *
from tensorflow.keras.preprocessing.image import load_img
from sklearn.metrics import f1_score

import matplotlib.pyplot as plt
import seaborn as sns
# Miscellaneous
from tqdm import tqdm
import os
import pandas as pd
import random
from collections import Counter
# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# !gdown "https://drive.google.com/uc?id=1BNQdJotVpohNrJ-j-JG1F5LSPAjY7mo2"
# !ls -l
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1BNQdJotVpohNrJ-j-JG1F5LSPAjY7mo2
# To: /content/archive.zip
# 100% 156M/156M [00:03<00:00, 40.5MB/s]
# total 152144
# -rw-r--r-- 1 root root 155791278 May 15 02:02 archive.zip
# drwxr-xr-x 1 root root      4096 May 11 16:35 sample_data

# %%
with zipfile.ZipFile('archive.zip', 'r') as zip_ref:
    # Extract all files from the archive
    zip_ref.extractall()

# %%
train_dir = '/content/Training/'
test_dir = '/content/Testing/'

# %%
train_paths = []
train_labels = []

for label in os.listdir(train_dir):
    for image in os.listdir(train_dir+label):
        train_paths.append(train_dir+label+'/'+image)
        train_labels.append(label)

train_paths, train_labels = shuffle(train_paths, train_labels)

# %%
test_paths = []
test_labels = []

for label in os.listdir(test_dir):
    for image in os.listdir(test_dir+label):
        test_paths.append(test_dir+label+'/'+image)
        test_labels.append(label)

test_paths, test_labels = shuffle(test_paths, test_labels)

# %%
train_paths[:5]
# Out:
# ['/content/Training/meningioma/Tr-me_0755.jpg',
#  '/content/Training/glioma/Tr-gl_0664.jpg',
#  '/content/Training/meningioma/Tr-me_0036.jpg',
#  '/content/Training/glioma/Tr-gl_0180.jpg',
#  '/content/Training/notumor/Tr-no_0673.jpg']

# %%
Counter(test_labels).keys()
# Out:
# dict_keys(['meningioma', 'glioma', 'pituitary', 'notumor'])

# %%
Counter(test_labels).values()
# Out:
# dict_values([306, 300, 300, 405])

# %%
plt.figure(figsize=(10,8))
colors = ['#ff9999','#66b3ff','#99ff99','#ffcc99']
plt.rcParams.update({'font.size': 14})
plt.pie(Counter(test_labels).values(), labels=Counter(test_labels).keys(),
         autopct='%.1f%%', explode=(0.025,0.025,0.025,0.025), labeldistance=1.15, colors = colors,
        startangle=30)
centre_circle = plt.Circle((0,0),0.30,fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
# plt.title("Distribution of labels of brain tumor", y = 1.05, fontsize = 18)
plt.tight_layout()

# %% [markdown]
# # Data Argumentation

# %%
# random augment of imput
def augment_image(image):
    image = Image.fromarray(np.uint8(image))
    # image = ImageEnhance.Brightness(image).enhance(random.uniform(0.8,1.2))
    # image = ImageEnhance.Contrast(image).enhance(random.uniform(0.8,1.2))
    image = np.array(image)/255.0
    return image

# %%
IMAGE_SIZE = 128
def open_images(paths):
    '''
    Given a list of paths to images, this function returns the images as arrays (after augmenting them)
    '''
    images = []
    for path in paths:
        image = load_img(path, target_size=(IMAGE_SIZE,IMAGE_SIZE))
        image = augment_image(image)
        images.append(image)
    return np.array(images)

# %%
images = open_images(train_paths[50:59])
labels = train_labels[50:59]
fig = plt.figure(figsize=(12, 6))
for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(labels[x])
    plt.imshow(images[x])
plt.rcParams.update({'font.size': 12})
plt.show()

# %%
X_train = open_images(train_paths)
X_train.shape
# Out:
# (5712, 128, 128, 3)

# %%
X_test = open_images(test_paths)
X_test.shape
# Out:
# (1311, 128, 128, 3)

# %%
labels = sorted(set(train_labels))
print(labels)
label2idx = {l: i for i, l in enumerate(labels)}
idx2label = {i: l for i, l in enumerate(labels)}
# Out:
# ['glioma', 'meningioma', 'notumor', 'pituitary']

# %%
y_train = np.array([label2idx[label] for label in train_labels]).ravel()
y_test = np.array([label2idx[label] for label in test_labels]).ravel()

# %%
# Split off 20% of train data for validation set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=109)

# %%
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((4569, 128, 128, 3), (1143, 128, 128, 3), (4569,), (1143,))

# %%
datagen_aug = tf.keras.preprocessing.image.ImageDataGenerator(
      # customize these and other parameters
      rotation_range=15,
      width_shift_range=1,
      height_shift_range=1,
      shear_range= 5,
      zoom_range=0.1,
      horizontal_flip=True,
      fill_mode='nearest',
)

# %%
X_train2 = X_train.copy()
X_train_more = X_train.copy()
y_train_more = y_train.copy()
# datagen_aug.fit(X_train2)

# for i in range(10):
#     for x_batch, y_batch in datagen_aug.flow(X_train2, y_train, batch_size=128):
#         X_train_more = np.append(X_train_more, x_batch.reshape(128, 128, 128, 3), axis = 0)
#         y_train_more = np.append(y_train_more, y_batch)
#         break
X_train_more.shape, y_train_more.shape
# Out:
# ((4569, 128, 128, 3), (4569,))

# %%
# plot argumnetation data
fig = plt.figure(figsize=(12, 6))
for x in range(1, 9):
    fig.add_subplot(2, 4, x)
    plt.axis('off')
    plt.title(f'{idx2label[y_train_more[x+2090]]} : {y_train_more[x+2090]}')
    plt.imshow(X_train_more[x+2090])
plt.rcParams.update({'font.size': 12})
plt.show()

# %% [markdown]
# # Dataset pipline

# %%
def dataset_pipline(x,y):
    dataset = tf.data.Dataset.from_tensor_slices((x, y))
    dataset = dataset.shuffle(buffer_size=len(x))
    dataset = dataset.batch(batch_size = 128)
    dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
    return dataset

# %%
dataset_train = dataset_pipline(X_train_more,y_train_more)
dataset_val = dataset_pipline(X_val,y_val)
dataset_test = dataset_pipline(X_test,y_test)

# %%
# tf.data.Dataset.save(dataset_train, "dataset/train")
# tf.data.Dataset.save(dataset_val, "dataset/val")
# tf.data.Dataset.save(dataset_test, "dataset/test")

# %% [markdown]
# # Helper function

# %%
def plot_history(model, title):
    # plot 'Loss'
    fig, axs = plt.subplots(1, 2, figsize=(16, 6))
    axs[0].plot(model.history.history['loss'], label='train')
    axs[0].plot(model.history.history['val_loss'], label='validation')
    axs[0].set_xlabel('Epoch')
    axs[0].set_ylabel('Cross-Entropy Loss')
    best_loss = np.nanmin(model.history.history['val_loss'])
    axs[0].axvline(np.nanargmin(model.history.history['val_loss']),
                c='k', ls='--',
                label=f'best val loss = {best_loss:.2f}')
    axs[0].legend()
    axs[0].set_title(f'Training and Validation Loss - {title}')

    # in case the Network has multiple outputs
    train_accuracy = []
    val_accuracy = []

    for cur_history in model.history.history:
        if 'accuracy'in cur_history:
            if 'val' in cur_history:
                val_accuracy.append(model.history.history[cur_history])
            else:
                train_accuracy.append(model.history.history[cur_history])

    train_accuracy = np.mean(np.array(train_accuracy), axis=0)
    val_accuracy = np.mean(np.array(val_accuracy), axis = 0)

    # plot 'Accuracy'
    axs[1].plot(train_accuracy, label='train')
    axs[1].plot(val_accuracy, label='validation')
    axs[1].set_xlabel('Epoch')
    axs[1].set_ylabel('Accuracy')
    best_accuracy = np.nanmax(val_accuracy)
    axs[1].axvline(np.nanargmax(val_accuracy),
                c='k', ls='--',
                label=f'best val accuracy = {best_accuracy:.5f}')
    axs[1].legend()
    axs[1].set_title(f'Training and Validation Accuracy - {title}')
    plt.tight_layout()

# %%
def plot_model_result(model_name,history):
    """Visualize the training loss and accuracy"""
    # Plot the training and validation loss
    fig, ax = plt.subplots(1, 2, figsize=(16,6))
    ax = ax.ravel()
    plt.sca(ax[0])
    plt.plot(history.history['accuracy'], label='train')
    plt.plot(history.history['val_accuracy'], label='validation')
    # plt.xticks(np.arange(10), np.arange(1,11))
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title(f'Training and Validation Accuracy - {model_name}')
    plt.legend()

    plt.sca(ax[1])
    plt.plot(history.history['loss'], label='train')
    plt.plot(history.history['val_loss'], label='validation')
    # plt.xticks(np.arange(10), np.arange(1,11))
    plt.xlabel('Epoch')
    plt.ylabel('Cross-Entropy Loss')
    plt.title(f'Training and Validation Loss - {model_name}')
    plt.legend()
    plt.tight_layout()

# %%
def plot_f1_score(model_name, f1_scores):
    f1_scores_dict = {label: score for label, score in zip(labels, f1_scores)}
    plt.subplots(figsize=(8,5), dpi =100)
    plt.bar(list(f1_scores_dict.keys()), list(f1_scores_dict.values()))
    for i in range(4):
        plt.text(i, f1_scores[i]/3,
              str(np.round(f1_scores[i], 4))+'\n',
              ha='center', va='bottom', color='white', weight='bold', fontsize = 18)
    plt.xlabel('Label')
    plt.ylabel('F1 Score')
    plt.title(f'F1 Score for Different Categories-{model_name}')
    plt.tight_layout()

# %%
def plot_confusion_matrix(y_label, y_pred, title='Confusion matrix'):
    y_label = np.array(y_label).ravel()
    y_pred = np.array(y_pred).ravel()

    classes = np.unique(y_label)
    cm = np.zeros((len(classes), len(classes)))
    for i in range(len(classes)):
        for j in range(len(classes)):
            cm[i, j] = np.sum((y_pred == classes[i]) & (y_label == classes[j]))

    cm_percentage =  cm / np.sum(cm, axis=0)

    # Plot confusion matrix
    plt.figure(figsize=(7,7))
    plt.imshow(cm_percentage.T, cmap=plt.cm.Blues)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, ["predict-" + s[:1] for s in labels])
    plt.yticks(tick_marks, labels)

    for i in range(len(classes)):
        for j in range(len(classes)):
            num_items = cm[i, j]
            pct_items = cm_percentage[i, j]
            plt.text(i, j,  f'{pct_items*100:.2f}% \n {num_items} ', ha="center", va="center",
                     color="white" if  cm_percentage[i, j] > 0.6 else "black")
    plt.tight_layout()

# %%
def save_accuarcy(model_name,train_loss, train_acc, test_loss, test_acc, f1_scores):
    print(f"Model Name: {model_name}")
    model_dict = {}

    model_dict["Name"] = model_name
    model_dict["Train Accuracy"] = train_acc
    model_dict["Train Loss"] = train_loss
    model_dict["Test Accuracy"] = test_acc
    model_dict["Test Loss"] = test_loss
    model_dict["f1"] = f1_scores

    return model_dict

# %% [markdown]
# # Build model

# %% [markdown]
# ## Simple CNN

# %%
model = Sequential(name="Self_built_Model1")
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(Convolution2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Convolution2D(128, (3,3), activation='relu'))
model.add(MaxPooling2D(2,2))
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(labels), activation='softmax'))

# plot model architecture
keras.utils.plot_model(model, show_shapes=True)

# compile model
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(model.summary())
# fit model
history = model.fit(dataset_train, epochs=50, batch_size=256,
                   validation_data = dataset_val, callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Model: "Self_built_Model1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 126, 126, 128)     3584
#
#  max_pooling2d (MaxPooling2D  (None, 63, 63, 128)      0
#  )
#
#  conv2d_1 (Conv2D)           (None, 61, 61, 128)       147584
#
#  max_pooling2d_1 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  flatten (Flatten)           (None, 115200)            0
#
#  dropout (Dropout)           (None, 115200)            0
#
#  dense (Dense)               (None, 128)               14745728
#
#  dropout_1 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 14,897,412
# Trainable params: 14,897,412
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/50
# 36/36 [==============================] - 22s 273ms/step - loss: 1.0597 - accuracy: 0.5966 - val_loss: 0.5176 - val_accuracy: 0.8250
# Epoch 2/50
# 36/36 [==============================] - 6s 167ms/step - loss: 0.4529 - accuracy: 0.8269 - val_loss: 0.3607 - val_accuracy: 0.8836
# Epoch 3/50
# 36/36 [==============================] - 6s 167ms/step - loss: 0.3104 - accuracy: 0.8871 - val_loss: 0.3167 - val_accuracy: 0.8828
# Epoch 4/50
# 36/36 [==============================] - 6s 168ms/step - loss: 0.2346 - accuracy: 0.9160 - val_loss: 0.2628 - val_accuracy: 0.9055
# Epoch 5/50
# 36/36 [==============================] - 6s 169ms/step - loss: 0.1668 - accuracy: 0.9416 - val_loss: 0.2675 - val_accuracy: 0.9046
# Epoch 6/50
# 36/36 [==============================] - 6s 169ms/step - loss: 0.1372 - accuracy: 0.9534 - val_loss: 0.2338 - val_accuracy: 0.9143
# Epoch 7/50
# 36/36 [==============================] - 6s 169ms/step - loss: 0.1116 - accuracy: 0.9582 - val_loss: 0.2070 - val_accuracy: 0.9256
# Epoch 8/50
# 36/36 [==============================] - 6s 169ms/step - loss: 0.0850 - accuracy: 0.9713 - val_loss: 0.1915 - val_accuracy: 0.9344
# Epoch 9/50
# 36/36 [==============================] - 6s 169ms/step - loss: 0.0719 - accuracy: 0.9748 - val_loss: 0.2356 - val_accuracy: 0.9300
# Epoch 10/50
# 36/36 [==============================] - 6s 168ms/step - loss: 0.0564 - accuracy: 0.9799 - val_loss: 0.1951 - val_accuracy: 0.9414
# Epoch 11/50
# 36/36 [==============================] - 6s 168ms/step - loss: 0.0355 - accuracy: 0.9899 - val_loss: 0.2245 - val_accuracy: 0.9379
# Epoch 12/50
# 36/36 [==============================] - 6s 168ms/step - loss: 0.0318 - accuracy: 0.9902 - val_loss: 0.2207 - val_accuracy: 0.9458
# Epoch 13/50
# 36/36 [==============================] - 6s 168ms/step - loss: 0.0286 - accuracy: 0.9910 - val_loss: 0.2265 - val_accuracy: 0.9501

# %%
plot_history(model, "Self Built Model1")

# %%
train_loss, train_acc = model.evaluate(dataset_train)
test_loss, test_acc = model.evaluate(dataset_test)
print(f'The train accuracy is {train_acc}')
print(f'The test accuracy is {test_acc}')
# Out:
# 36/36 [==============================] - 2s 52ms/step - loss: 0.0065 - accuracy: 0.9998
# 11/11 [==============================] - 1s 83ms/step - loss: 0.2318 - accuracy: 0.9397
# The train accuracy is 0.9997811317443848
# The test accuracy is 0.9397406578063965

# %%
y_prob = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_prob, axis=-1)
f1_scores = f1_score(y_test.ravel(), y_pred.ravel(), average=None)

# plot f1 score
plot_f1_score("Self Built Model1", f1_scores)
# plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
model_results=[]
model_results.append(save_accuarcy("Self Built Model1",train_loss, train_acc, test_loss, test_acc, f1_scores))
# Out:
# Model Name: Self Built Model1

# %% [markdown]
# ## Vgg 16

# %%
vgg16_model = VGG16(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), include_top=False, weights='imagenet')
# Set all layers to non-trainable
for layer in vgg16_model.layers:
    layer.trainable = False
# Set the last vgg block to trainable
vgg16_model.layers[-2].trainable = True
vgg16_model.layers[-3].trainable = True
vgg16_model.layers[-4].trainable = True

model = Sequential(name="vgg_16")
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(vgg16_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(labels), activation='softmax'))

# plot model architecture
keras.utils.plot_model(model, show_shapes=True)

# compile model
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(model.summary())
# fit model
history = model.fit(dataset_train, epochs=50, batch_size=256,
                   validation_data = dataset_val, callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Model: "vgg_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten_1 (Flatten)         (None, 8192)              0
#
#  dropout_2 (Dropout)         (None, 8192)              0
#
#  dense_2 (Dense)             (None, 128)               1048704
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 15,763,908
# Trainable params: 8,128,644
# Non-trainable params: 7,635,264
# _________________________________________________________________
# None
# Epoch 1/50
# 36/36 [==============================] - 25s 497ms/step - loss: 0.6685 - accuracy: 0.7352 - val_loss: 0.3813 - val_accuracy: 0.8495
# Epoch 2/50
# 36/36 [==============================] - 8s 230ms/step - loss: 0.2851 - accuracy: 0.8956 - val_loss: 0.2193 - val_accuracy: 0.9178
# Epoch 3/50
# 36/36 [==============================] - 8s 227ms/step - loss: 0.1970 - accuracy: 0.9245 - val_loss: 0.1998 - val_accuracy: 0.9221
# Epoch 4/50
# 36/36 [==============================] - 8s 225ms/step - loss: 0.1464 - accuracy: 0.9413 - val_loss: 0.1917 - val_accuracy: 0.9283
# Epoch 5/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.1120 - accuracy: 0.9586 - val_loss: 0.1403 - val_accuracy: 0.9484
# Epoch 6/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.0735 - accuracy: 0.9731 - val_loss: 0.1412 - val_accuracy: 0.9510
# Epoch 7/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0575 - accuracy: 0.9786 - val_loss: 0.1636 - val_accuracy: 0.9379
# Epoch 8/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0469 - accuracy: 0.9845 - val_loss: 0.1516 - val_accuracy: 0.9493
# Epoch 9/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0346 - accuracy: 0.9897 - val_loss: 0.1534 - val_accuracy: 0.9458
# Epoch 10/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0140 - accuracy: 0.9965 - val_loss: 0.1230 - val_accuracy: 0.9641
# Epoch 11/50
# 36/36 [==============================] - 8s 225ms/step - loss: 0.0146 - accuracy: 0.9952 - val_loss: 0.1507 - val_accuracy: 0.9589
# Epoch 12/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.0228 - accuracy: 0.9928 - val_loss: 0.1369 - val_accuracy: 0.9624
# Epoch 13/50
# 36/36 [==============================] - 8s 225ms/step - loss: 0.0116 - accuracy: 0.9972 - val_loss: 0.1370 - val_accuracy: 0.9633
# Epoch 14/50
# 36/36 [==============================] - 8s 226ms/step - loss: 0.0057 - accuracy: 0.9991 - val_loss: 0.1170 - val_accuracy: 0.9659
# Epoch 15/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.0036 - accuracy: 0.9996 - val_loss: 0.1160 - val_accuracy: 0.9659
# Epoch 16/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.0018 - accuracy: 0.9998 - val_loss: 0.1297 - val_accuracy: 0.9703
# Epoch 17/50
# 36/36 [==============================] - 8s 224ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.1261 - val_accuracy: 0.9685
# Epoch 18/50
# 36/36 [==============================] - 8s 224ms/step - loss: 8.3292e-04 - accuracy: 0.9998 - val_loss: 0.1397 - val_accuracy: 0.9659
# Epoch 19/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0014 - accuracy: 0.9998 - val_loss: 0.1468 - val_accuracy: 0.9676
# Epoch 20/50
# 36/36 [==============================] - 8s 223ms/step - loss: 0.0118 - accuracy: 0.9952 - val_loss: 0.1489 - val_accuracy: 0.9563

# %%
plot_history(model, "Vgg 16")

# %%
train_loss, train_acc = model.evaluate(dataset_train)
test_loss, test_acc = model.evaluate(dataset_test)
print(f'The train accuracy is {train_acc}')
print(f'The test accuracy is {test_acc}')
# Out:
# 36/36 [==============================] - 6s 161ms/step - loss: 0.0065 - accuracy: 0.9987
# 11/11 [==============================] - 3s 324ms/step - loss: 0.1115 - accuracy: 0.9672
# The train accuracy is 0.9986867904663086
# The test accuracy is 0.9672006368637085

# %%
y_prob = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_prob, axis=-1)
f1_scores = f1_score(y_test.ravel(), y_pred.ravel(), average=None)

# plot f1 score
plot_f1_score("Vgg 16", f1_scores)
# plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
model_results.append(save_accuarcy("Vgg 16",train_loss, train_acc, test_loss, test_acc, f1_scores))
# Out:
# Model Name: Vgg 16

# %% [markdown]
# ## ResNet 50

# %%
resnet50_model = ResNet50(input_shape=(IMAGE_SIZE,IMAGE_SIZE,3), include_top=False, weights='imagenet')
# Set all layers to non-trainable
for layer in resnet50_model.layers:
    layer.trainable = False
# Set the last resnet block to trainable
resnet50_model.layers[-2].trainable = True
resnet50_model.layers[-3].trainable = True
resnet50_model.layers[-4].trainable = True

model = Sequential(name="ResNet50")
model.add(Input(shape=(IMAGE_SIZE,IMAGE_SIZE,3)))
model.add(resnet50_model)
model.add(Flatten())
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(len(labels), activation='softmax'))

# plot model architecture
keras.utils.plot_model(model, show_shapes=True)

# compile model
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(model.summary())
# fit model
history = model.fit(dataset_train, epochs=50, batch_size=256,
                   validation_data = dataset_val, callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 [==============================] - 5s 0us/step
# Model: "ResNet50"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet50 (Functional)       (None, 4, 4, 2048)        23587712
#
#  flatten_2 (Flatten)         (None, 32768)             0
#
#  dropout_4 (Dropout)         (None, 32768)             0
#
#  dense_4 (Dense)             (None, 256)               8388864
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_5 (Dense)             (None, 4)                 1028
#
# =================================================================
# Total params: 31,977,604
# Trainable params: 9,444,612
# Non-trainable params: 22,532,992
# _________________________________________________________________
# None
# Epoch 1/50
# 36/36 [==============================] - 15s 259ms/step - loss: 1.6562 - accuracy: 0.5923 - val_loss: 1.2086 - val_accuracy: 0.5136
# Epoch 2/50
# 36/36 [==============================] - 6s 165ms/step - loss: 0.5955 - accuracy: 0.7636 - val_loss: 1.0985 - val_accuracy: 0.6483
# Epoch 3/50
# 36/36 [==============================] - 6s 166ms/step - loss: 0.5119 - accuracy: 0.7936 - val_loss: 1.0724 - val_accuracy: 0.6325
# Epoch 4/50
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4391 - accuracy: 0.8253 - val_loss: 0.8733 - val_accuracy: 0.7017
# Epoch 5/50
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4432 - accuracy: 0.8172 - val_loss: 0.7222 - val_accuracy: 0.7349
# Epoch 6/50
# 36/36 [==============================] - 6s 166ms/step - loss: 0.4100 - accuracy: 0.8394 - val_loss: 0.6027 - val_accuracy: 0.7629
# Epoch 7/50
# 36/36 [==============================] - 6s 165ms/step - loss: 0.3929 - accuracy: 0.8483 - val_loss: 0.6200 - val_accuracy: 0.7480
# Epoch 8/50
# 36/36 [==============================] - 6s 165ms/step - loss: 0.3918 - accuracy: 0.8426 - val_loss: 0.4367 - val_accuracy: 0.8259
# Epoch 9/50
# 36/36 [==============================] - 6s 164ms/step - loss: 0.3381 - accuracy: 0.8630 - val_loss: 0.4966 - val_accuracy: 0.8110
# Epoch 10/50
# 36/36 [==============================] - 6s 164ms/step - loss: 0.3371 - accuracy: 0.8678 - val_loss: 0.5934 - val_accuracy: 0.7305
# Epoch 11/50
# 36/36 [==============================] - 6s 164ms/step - loss: 0.3446 - accuracy: 0.8601 - val_loss: 0.8131 - val_accuracy: 0.7358
# Epoch 12/50
# 36/36 [==============================] - 6s 164ms/step - loss: 0.3270 - accuracy: 0.8731 - val_loss: 0.6915 - val_accuracy: 0.7402
# Epoch 13/50
# 36/36 [==============================] - 6s 164ms/step - loss: 0.3091 - accuracy: 0.8755 - val_loss: 1.0871 - val_accuracy: 0.7192

# %%
plot_history(model, "ResNet50")

# %%
train_loss, train_acc = model.evaluate(dataset_train)
test_loss, test_acc = model.evaluate(dataset_test)
print(f'The train accuracy is {train_acc}')
print(f'The test accuracy is {test_acc}')
# Out:
# 36/36 [==============================] - 5s 126ms/step - loss: 0.9288 - accuracy: 0.7192
# 11/11 [==============================] - 2s 171ms/step - loss: 1.1909 - accuracy: 0.6979
# The train accuracy is 0.7191945910453796
# The test accuracy is 0.6979405283927917

# %%
y_prob = model.predict(X_test, verbose=0)
y_pred = np.argmax(y_prob, axis=-1)
f1_scores = f1_score(y_test.ravel(), y_pred.ravel(), average=None)

# plot f1 score
plot_f1_score("ResNet50", f1_scores)
# plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
model_results.append(save_accuarcy("ResNet50",train_loss, train_acc, test_loss, test_acc, f1_scores))
# Out:
# Model Name: ResNet50

# %% [markdown]
# ## GoogleNet

# %%
def inception_block(input_tensor, filters):
    # Branch 1
    branch1 = Conv2D(filters[0], (1,1), activation='relu')(input_tensor)

    # Branch 2
    branch2 = Conv2D(filters[1], (1,1), activation='relu')(input_tensor)
    branch2 = Conv2D(filters[2], (3,3), padding='same', activation='relu')(branch2)

    # Branch 3
    branch3 = Conv2D(filters[3], (1,1), activation='relu')(input_tensor)
    branch3 = Conv2D(filters[4], (5,5), padding='same', activation='relu')(branch3)

    # Branch 4
    branch4 = MaxPool2D((3,3), strides=(1,1), padding='same')(input_tensor)
    branch4 = Conv2D(filters[5], (1,1), activation='relu')(branch4)

    # Concatenate branches
    output_tensor = concatenate([branch1, branch2, branch3, branch4], axis=-1)

    return output_tensor

# %%
def auxiliary_block(input_tensor, aux_name):
    X = AveragePooling2D(pool_size = (5,5), strides = (3,3), padding='same')(input_tensor)
    X = Conv2D(filters = 128, kernel_size = (1,1), padding = 'same', activation = 'relu')(X)
    X = Flatten()(X)
    X = Dense(1024, activation = 'relu')(X)
    X = Dropout(0.7)(X)
    output_tensor = Dense(4, activation = 'softmax', name = aux_name)(X)

    return output_tensor

# %%
def GoogleNet(input_shape):
    inp = Input(shape=input_shape)

    X = Conv2D(64, (7,7), strides=(2,2), padding='same', activation='relu')(inp)
    X = MaxPool2D((3,3), strides=(2,2), padding='same')(X)
    X = Conv2D(64, (1,1), activation='relu')(X)
    X = Conv2D(192, (3,3), padding='same', activation='relu')(X)
    X = MaxPool2D((3,3), strides=(2,2), padding='same')(X)

    # First Inception blocks (x2)
    X = inception_block(X, [64, 96, 128, 16, 32, 32])
    X = inception_block(X, [128, 128, 192, 32, 96, 64])
    X = MaxPool2D((3,3), strides=(2,2), padding='same')(X)

    # Second Inception blocks (x5)
    X = inception_block(X, [192, 96, 208, 16, 48, 64])
    X = inception_block(X, [160, 112, 224, 24, 64, 64])
    X1 = auxiliary_block(X, aux_name = 'aux_output1') # First Auxiliary block

    X = inception_block(X, [128, 128, 256, 24, 64, 64])
    X = inception_block(X, [112, 144, 288, 32, 64, 64])
    X = inception_block(X, [256, 160, 320, 32, 128, 128])
    X2 = auxiliary_block(X, aux_name = 'aux_output2') # Second Auxiliary block

    # Third Inception blocks (x2)
    X = MaxPool2D((3,3), strides=(2,2), padding='same')(X)
    X = inception_block(X, [256, 160, 320, 32, 128, 128])
    X = inception_block(X, [384, 192, 384, 48, 128, 128])
    X = GlobalAvgPool2D()(X)
    X = Dense(4, activation='softmax', name='main_output')(X)
    model = Model(inputs=inp, outputs=[X, X1, X2])

    return model

# %%
input_shape = (IMAGE_SIZE,IMAGE_SIZE,3)
model = GoogleNet(input_shape)

# plot model architecture
keras.utils.plot_model(model, show_shapes=True)

# compile model
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(model.summary())
# fit model
history = model.fit(dataset_train, epochs=50, batch_size=256,
                   validation_data = dataset_val, callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_6 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 64)   9472        ['input_6[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 64)  0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 32, 32, 64)   4160        ['max_pooling2d_2[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 192)  110784      ['conv2d_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 192)  0          ['conv2d_4[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 96)   18528       ['max_pooling2d_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 16, 16, 16)   3088        ['max_pooling2d_3[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 192)  0          ['max_pooling2d_3[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 16, 16, 64)   12352       ['max_pooling2d_3[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  110720      ['conv2d_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 16, 16, 32)   12832       ['conv2d_8[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 16, 16, 32)   6176        ['max_pooling2d_4[0][0]']
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_5[0][0]',
#                                                                   'conv2d_7[0][0]',
#                                                                   'conv2d_9[0][0]',
#                                                                   'conv2d_10[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 16, 16, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 16, 16, 32)   8224        ['concatenate[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 16, 16, 256)  0          ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 16, 16, 128)  32896       ['concatenate[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 16, 16, 192)  221376      ['conv2d_12[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 16, 16, 96)   76896       ['conv2d_14[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 16, 16, 64)   16448       ['max_pooling2d_5[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 16, 16, 480)  0           ['conv2d_11[0][0]',
#                                                                   'conv2d_13[0][0]',
#                                                                   'conv2d_15[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 8, 8, 480)   0           ['concatenate_1[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 8, 8, 96)     46176       ['max_pooling2d_6[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 16)     7696        ['max_pooling2d_6[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 480)   0           ['max_pooling2d_6[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 8, 8, 192)    92352       ['max_pooling2d_6[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 208)    179920      ['conv2d_18[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 48)     19248       ['conv2d_20[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 64)     30784       ['max_pooling2d_7[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 8, 8, 512)    0           ['conv2d_17[0][0]',
#                                                                   'conv2d_19[0][0]',
#                                                                   'conv2d_21[0][0]',
#                                                                   'conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 112)    57456       ['concatenate_2[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 24)     12312       ['concatenate_2[0][0]']
#
#  max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 512)   0           ['concatenate_2[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 160)    82080       ['concatenate_2[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 224)    226016      ['conv2d_24[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 64)     38464       ['conv2d_26[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 8, 8, 64)     32832       ['max_pooling2d_8[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 8, 8, 512)    0           ['conv2d_23[0][0]',
#                                                                   'conv2d_25[0][0]',
#                                                                   'conv2d_27[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 8, 8, 128)    65664       ['concatenate_3[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 8, 8, 24)     12312       ['concatenate_3[0][0]']
#
#  max_pooling2d_9 (MaxPooling2D)  (None, 8, 8, 512)   0           ['concatenate_3[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 8, 8, 128)    65664       ['concatenate_3[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 8, 8, 256)    295168      ['conv2d_31[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 8, 8, 64)     38464       ['conv2d_33[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 8, 8, 64)     32832       ['max_pooling2d_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 8, 8, 512)    0           ['conv2d_30[0][0]',
#                                                                   'conv2d_32[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 8, 8, 144)    73872       ['concatenate_4[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 32)     16416       ['concatenate_4[0][0]']
#
#  max_pooling2d_10 (MaxPooling2D  (None, 8, 8, 512)   0           ['concatenate_4[0][0]']
#  )
#
#  conv2d_36 (Conv2D)             (None, 8, 8, 112)    57456       ['concatenate_4[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 8, 8, 288)    373536      ['conv2d_37[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 64)     51264       ['conv2d_39[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 8, 8, 64)     32832       ['max_pooling2d_10[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 8, 8, 528)    0           ['conv2d_36[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'conv2d_40[0][0]',
#                                                                   'conv2d_41[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 8, 8, 160)    84640       ['concatenate_5[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 8, 8, 32)     16928       ['concatenate_5[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 8, 8, 528)   0           ['concatenate_5[0][0]']
#  )
#
#  conv2d_42 (Conv2D)             (None, 8, 8, 256)    135424      ['concatenate_5[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 8, 8, 320)    461120      ['conv2d_43[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 8, 8, 128)    102528      ['conv2d_45[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 8, 8, 128)    67712       ['max_pooling2d_11[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 8, 8, 832)    0           ['conv2d_42[0][0]',
#                                                                   'conv2d_44[0][0]',
#                                                                   'conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 4, 4, 832)   0           ['concatenate_6[0][0]']
#  )
#
#  conv2d_50 (Conv2D)             (None, 4, 4, 160)    133280      ['max_pooling2d_12[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 4, 4, 32)     26656       ['max_pooling2d_12[0][0]']
#
#  max_pooling2d_13 (MaxPooling2D  (None, 4, 4, 832)   0           ['max_pooling2d_12[0][0]']
#  )
#
#  conv2d_49 (Conv2D)             (None, 4, 4, 256)    213248      ['max_pooling2d_12[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 4, 4, 320)    461120      ['conv2d_50[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 4, 4, 128)    102528      ['conv2d_52[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 4, 4, 128)    106624      ['max_pooling2d_13[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 4, 4, 832)    0           ['conv2d_49[0][0]',
#                                                                   'conv2d_51[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'conv2d_54[0][0]']
#
#  average_pooling2d (AveragePool  (None, 3, 3, 512)   0           ['concatenate_3[0][0]']
#  ing2D)
#
#  average_pooling2d_1 (AveragePo  (None, 3, 3, 832)   0           ['concatenate_6[0][0]']
#  oling2D)
#
#  conv2d_56 (Conv2D)             (None, 4, 4, 192)    159936      ['concatenate_7[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 4, 4, 48)     39984       ['concatenate_7[0][0]']
#
#  max_pooling2d_14 (MaxPooling2D  (None, 4, 4, 832)   0           ['concatenate_7[0][0]']
#  )
#
#  conv2d_29 (Conv2D)             (None, 3, 3, 128)    65664       ['average_pooling2d[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 3, 3, 128)    106624      ['average_pooling2d_1[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 4, 4, 384)    319872      ['concatenate_7[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 4, 4, 384)    663936      ['conv2d_56[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 4, 4, 128)    153728      ['conv2d_58[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 4, 4, 128)    106624      ['max_pooling2d_14[0][0]']
#
#  flatten_3 (Flatten)            (None, 1152)         0           ['conv2d_29[0][0]']
#
#  flatten_4 (Flatten)            (None, 1152)         0           ['conv2d_48[0][0]']
#
#  concatenate_8 (Concatenate)    (None, 4, 4, 1024)   0           ['conv2d_55[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'conv2d_59[0][0]',
#                                                                   'conv2d_60[0][0]']
#
#  dense_6 (Dense)                (None, 1024)         1180672     ['flatten_3[0][0]']
#
#  dense_7 (Dense)                (None, 1024)         1180672     ['flatten_4[0][0]']
#
#  global_average_pooling2d (Glob  (None, 1024)        0           ['concatenate_8[0][0]']
#  alAveragePooling2D)
#
#  dropout_6 (Dropout)            (None, 1024)         0           ['dense_6[0][0]']
#
#  dropout_7 (Dropout)            (None, 1024)         0           ['dense_7[0][0]']
#
#  main_output (Dense)            (None, 4)            4100        ['global_average_pooling2d[0][0]'
#                                                                  ]
#
#  aux_output1 (Dense)            (None, 4)            4100        ['dropout_6[0][0]']
#
#  aux_output2 (Dense)            (None, 4)            4100        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 8,519,484
# Trainable params: 8,519,484
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 36/36 [==============================] - 39s 349ms/step - loss: 4.0303 - main_output_loss: 1.3399 - aux_output1_loss: 1.3482 - aux_output2_loss: 1.3421 - main_output_accuracy: 0.2731 - aux_output1_accuracy: 0.2747 - aux_output2_accuracy: 0.2716 - val_loss: 3.7179 - val_main_output_loss: 1.2019 - val_aux_output1_loss: 1.2839 - val_aux_output2_loss: 1.2321 - val_main_output_accuracy: 0.4287 - val_aux_output1_accuracy: 0.2940 - val_aux_output2_accuracy: 0.3745
# Epoch 2/50
# 36/36 [==============================] - 6s 160ms/step - loss: 3.4106 - main_output_loss: 1.1244 - aux_output1_loss: 1.1647 - aux_output2_loss: 1.1214 - main_output_accuracy: 0.4555 - aux_output1_accuracy: 0.4264 - aux_output2_accuracy: 0.4546 - val_loss: 3.0209 - val_main_output_loss: 0.9954 - val_aux_output1_loss: 1.0351 - val_aux_output2_loss: 0.9904 - val_main_output_accuracy: 0.4987 - val_aux_output1_accuracy: 0.6185 - val_aux_output2_accuracy: 0.5039
# Epoch 3/50
# 36/36 [==============================] - 6s 160ms/step - loss: 2.9518 - main_output_loss: 0.9845 - aux_output1_loss: 0.9806 - aux_output2_loss: 0.9867 - main_output_accuracy: 0.5143 - aux_output1_accuracy: 0.5881 - aux_output2_accuracy: 0.5161 - val_loss: 2.6624 - val_main_output_loss: 0.9029 - val_aux_output1_loss: 0.8638 - val_aux_output2_loss: 0.8957 - val_main_output_accuracy: 0.5967 - val_aux_output1_accuracy: 0.6859 - val_aux_output2_accuracy: 0.6150
# Epoch 4/50
# 36/36 [==============================] - 6s 159ms/step - loss: 2.3903 - main_output_loss: 0.7861 - aux_output1_loss: 0.8144 - aux_output2_loss: 0.7898 - main_output_accuracy: 0.6629 - aux_output1_accuracy: 0.6697 - aux_output2_accuracy: 0.6691 - val_loss: 1.9671 - val_main_output_loss: 0.6573 - val_aux_output1_loss: 0.6741 - val_aux_output2_loss: 0.6357 - val_main_output_accuracy: 0.7358 - val_aux_output1_accuracy: 0.7559 - val_aux_output2_accuracy: 0.7419
# Epoch 5/50
# 36/36 [==============================] - 6s 159ms/step - loss: 1.9984 - main_output_loss: 0.6579 - aux_output1_loss: 0.6867 - aux_output2_loss: 0.6538 - main_output_accuracy: 0.7363 - aux_output1_accuracy: 0.7328 - aux_output2_accuracy: 0.7395 - val_loss: 1.7022 - val_main_output_loss: 0.5505 - val_aux_output1_loss: 0.6020 - val_aux_output2_loss: 0.5497 - val_main_output_accuracy: 0.7918 - val_aux_output1_accuracy: 0.7935 - val_aux_output2_accuracy: 0.7988
# Epoch 6/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.7975 - main_output_loss: 0.5804 - aux_output1_loss: 0.6228 - aux_output2_loss: 0.5944 - main_output_accuracy: 0.7722 - aux_output1_accuracy: 0.7608 - aux_output2_accuracy: 0.7665 - val_loss: 1.6135 - val_main_output_loss: 0.5450 - val_aux_output1_loss: 0.5402 - val_aux_output2_loss: 0.5283 - val_main_output_accuracy: 0.7682 - val_aux_output1_accuracy: 0.7909 - val_aux_output2_accuracy: 0.7813
# Epoch 7/50
# 36/36 [==============================] - 6s 159ms/step - loss: 1.5705 - main_output_loss: 0.5040 - aux_output1_loss: 0.5502 - aux_output2_loss: 0.5163 - main_output_accuracy: 0.7997 - aux_output1_accuracy: 0.7870 - aux_output2_accuracy: 0.8030 - val_loss: 1.4744 - val_main_output_loss: 0.4899 - val_aux_output1_loss: 0.5134 - val_aux_output2_loss: 0.4710 - val_main_output_accuracy: 0.8136 - val_aux_output1_accuracy: 0.8180 - val_aux_output2_accuracy: 0.8206
# Epoch 8/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.4661 - main_output_loss: 0.4763 - aux_output1_loss: 0.5143 - aux_output2_loss: 0.4756 - main_output_accuracy: 0.8146 - aux_output1_accuracy: 0.8046 - aux_output2_accuracy: 0.8166 - val_loss: 1.2671 - val_main_output_loss: 0.4178 - val_aux_output1_loss: 0.4435 - val_aux_output2_loss: 0.4059 - val_main_output_accuracy: 0.8486 - val_aux_output1_accuracy: 0.8443 - val_aux_output2_accuracy: 0.8495
# Epoch 9/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.3971 - main_output_loss: 0.4504 - aux_output1_loss: 0.4862 - aux_output2_loss: 0.4604 - main_output_accuracy: 0.8232 - aux_output1_accuracy: 0.8155 - aux_output2_accuracy: 0.8186 - val_loss: 1.3086 - val_main_output_loss: 0.4430 - val_aux_output1_loss: 0.4490 - val_aux_output2_loss: 0.4166 - val_main_output_accuracy: 0.8451 - val_aux_output1_accuracy: 0.8338 - val_aux_output2_accuracy: 0.8591
# Epoch 10/50
# 36/36 [==============================] - 6s 157ms/step - loss: 1.2877 - main_output_loss: 0.4107 - aux_output1_loss: 0.4546 - aux_output2_loss: 0.4225 - main_output_accuracy: 0.8422 - aux_output1_accuracy: 0.8302 - aux_output2_accuracy: 0.8431 - val_loss: 1.3724 - val_main_output_loss: 0.4681 - val_aux_output1_loss: 0.4535 - val_aux_output2_loss: 0.4507 - val_main_output_accuracy: 0.8110 - val_aux_output1_accuracy: 0.8101 - val_aux_output2_accuracy: 0.8241
# Epoch 11/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.2752 - main_output_loss: 0.4048 - aux_output1_loss: 0.4537 - aux_output2_loss: 0.4167 - main_output_accuracy: 0.8481 - aux_output1_accuracy: 0.8350 - aux_output2_accuracy: 0.8453 - val_loss: 1.0470 - val_main_output_loss: 0.3372 - val_aux_output1_loss: 0.3742 - val_aux_output2_loss: 0.3356 - val_main_output_accuracy: 0.8661 - val_aux_output1_accuracy: 0.8705 - val_aux_output2_accuracy: 0.8705
# Epoch 12/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.0931 - main_output_loss: 0.3389 - aux_output1_loss: 0.4016 - aux_output2_loss: 0.3526 - main_output_accuracy: 0.8728 - aux_output1_accuracy: 0.8547 - aux_output2_accuracy: 0.8726 - val_loss: 1.0145 - val_main_output_loss: 0.3274 - val_aux_output1_loss: 0.3607 - val_aux_output2_loss: 0.3264 - val_main_output_accuracy: 0.8784 - val_aux_output1_accuracy: 0.8705 - val_aux_output2_accuracy: 0.8819
# Epoch 13/50
# 36/36 [==============================] - 6s 158ms/step - loss: 1.0306 - main_output_loss: 0.3172 - aux_output1_loss: 0.3814 - aux_output2_loss: 0.3320 - main_output_accuracy: 0.8805 - aux_output1_accuracy: 0.8626 - aux_output2_accuracy: 0.8790 - val_loss: 0.9463 - val_main_output_loss: 0.3104 - val_aux_output1_loss: 0.3382 - val_aux_output2_loss: 0.2977 - val_main_output_accuracy: 0.8801 - val_aux_output1_accuracy: 0.8705 - val_aux_output2_accuracy: 0.8863
# Epoch 14/50
# 36/36 [==============================] - 6s 159ms/step - loss: 1.0642 - main_output_loss: 0.3397 - aux_output1_loss: 0.3779 - aux_output2_loss: 0.3465 - main_output_accuracy: 0.8715 - aux_output1_accuracy: 0.8636 - aux_output2_accuracy: 0.8680 - val_loss: 0.9472 - val_main_output_loss: 0.3066 - val_aux_output1_loss: 0.3361 - val_aux_output2_loss: 0.3044 - val_main_output_accuracy: 0.8793 - val_aux_output1_accuracy: 0.8784 - val_aux_output2_accuracy: 0.8810
# Epoch 15/50
# 36/36 [==============================] - 6s 160ms/step - loss: 0.9199 - main_output_loss: 0.2819 - aux_output1_loss: 0.3442 - aux_output2_loss: 0.2939 - main_output_accuracy: 0.8960 - aux_output1_accuracy: 0.8772 - aux_output2_accuracy: 0.8963 - val_loss: 0.9360 - val_main_output_loss: 0.3075 - val_aux_output1_loss: 0.3249 - val_aux_output2_loss: 0.3036 - val_main_output_accuracy: 0.8819 - val_aux_output1_accuracy: 0.8828 - val_aux_output2_accuracy: 0.8801
# Epoch 16/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.8241 - main_output_loss: 0.2456 - aux_output1_loss: 0.3132 - aux_output2_loss: 0.2652 - main_output_accuracy: 0.9116 - aux_output1_accuracy: 0.8910 - aux_output2_accuracy: 0.9074 - val_loss: 0.9646 - val_main_output_loss: 0.3052 - val_aux_output1_loss: 0.3410 - val_aux_output2_loss: 0.3183 - val_main_output_accuracy: 0.8871 - val_aux_output1_accuracy: 0.8758 - val_aux_output2_accuracy: 0.8863
# Epoch 17/50
# 36/36 [==============================] - 6s 160ms/step - loss: 0.8471 - main_output_loss: 0.2565 - aux_output1_loss: 0.3149 - aux_output2_loss: 0.2757 - main_output_accuracy: 0.9094 - aux_output1_accuracy: 0.8897 - aux_output2_accuracy: 0.9041 - val_loss: 0.8259 - val_main_output_loss: 0.2707 - val_aux_output1_loss: 0.2948 - val_aux_output2_loss: 0.2604 - val_main_output_accuracy: 0.8950 - val_aux_output1_accuracy: 0.8933 - val_aux_output2_accuracy: 0.9064
# Epoch 18/50
# 36/36 [==============================] - 6s 160ms/step - loss: 0.7851 - main_output_loss: 0.2394 - aux_output1_loss: 0.2950 - aux_output2_loss: 0.2507 - main_output_accuracy: 0.9131 - aux_output1_accuracy: 0.8956 - aux_output2_accuracy: 0.9109 - val_loss: 1.1103 - val_main_output_loss: 0.3761 - val_aux_output1_loss: 0.3383 - val_aux_output2_loss: 0.3959 - val_main_output_accuracy: 0.8583 - val_aux_output1_accuracy: 0.8679 - val_aux_output2_accuracy: 0.8486
# Epoch 19/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.7840 - main_output_loss: 0.2395 - aux_output1_loss: 0.2941 - aux_output2_loss: 0.2503 - main_output_accuracy: 0.9118 - aux_output1_accuracy: 0.8947 - aux_output2_accuracy: 0.9070 - val_loss: 0.7443 - val_main_output_loss: 0.2321 - val_aux_output1_loss: 0.2729 - val_aux_output2_loss: 0.2394 - val_main_output_accuracy: 0.9221 - val_aux_output1_accuracy: 0.9099 - val_aux_output2_accuracy: 0.9134
# Epoch 20/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.6961 - main_output_loss: 0.2078 - aux_output1_loss: 0.2696 - aux_output2_loss: 0.2187 - main_output_accuracy: 0.9262 - aux_output1_accuracy: 0.9083 - aux_output2_accuracy: 0.9254 - val_loss: 0.7604 - val_main_output_loss: 0.2360 - val_aux_output1_loss: 0.2922 - val_aux_output2_loss: 0.2323 - val_main_output_accuracy: 0.9143 - val_aux_output1_accuracy: 0.8863 - val_aux_output2_accuracy: 0.9151
# Epoch 21/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.8313 - main_output_loss: 0.2571 - aux_output1_loss: 0.3086 - aux_output2_loss: 0.2655 - main_output_accuracy: 0.9100 - aux_output1_accuracy: 0.8890 - aux_output2_accuracy: 0.9059 - val_loss: 0.8212 - val_main_output_loss: 0.2599 - val_aux_output1_loss: 0.2972 - val_aux_output2_loss: 0.2641 - val_main_output_accuracy: 0.9108 - val_aux_output1_accuracy: 0.8880 - val_aux_output2_accuracy: 0.8994
# Epoch 22/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.6121 - main_output_loss: 0.1752 - aux_output1_loss: 0.2464 - aux_output2_loss: 0.1905 - main_output_accuracy: 0.9398 - aux_output1_accuracy: 0.9184 - aux_output2_accuracy: 0.9374 - val_loss: 0.6754 - val_main_output_loss: 0.2179 - val_aux_output1_loss: 0.2424 - val_aux_output2_loss: 0.2151 - val_main_output_accuracy: 0.9239 - val_aux_output1_accuracy: 0.9099 - val_aux_output2_accuracy: 0.9239
# Epoch 23/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.7419 - main_output_loss: 0.2413 - aux_output1_loss: 0.2664 - aux_output2_loss: 0.2343 - main_output_accuracy: 0.9146 - aux_output1_accuracy: 0.9085 - aux_output2_accuracy: 0.9181 - val_loss: 0.8188 - val_main_output_loss: 0.2936 - val_aux_output1_loss: 0.2544 - val_aux_output2_loss: 0.2708 - val_main_output_accuracy: 0.8845 - val_aux_output1_accuracy: 0.9073 - val_aux_output2_accuracy: 0.8950
# Epoch 24/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.6146 - main_output_loss: 0.1866 - aux_output1_loss: 0.2352 - aux_output2_loss: 0.1928 - main_output_accuracy: 0.9324 - aux_output1_accuracy: 0.9212 - aux_output2_accuracy: 0.9306 - val_loss: 0.6288 - val_main_output_loss: 0.1956 - val_aux_output1_loss: 0.2310 - val_aux_output2_loss: 0.2022 - val_main_output_accuracy: 0.9388 - val_aux_output1_accuracy: 0.9186 - val_aux_output2_accuracy: 0.9326
# Epoch 25/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.4953 - main_output_loss: 0.1403 - aux_output1_loss: 0.2034 - aux_output2_loss: 0.1517 - main_output_accuracy: 0.9523 - aux_output1_accuracy: 0.9370 - aux_output2_accuracy: 0.9512 - val_loss: 0.6598 - val_main_output_loss: 0.2139 - val_aux_output1_loss: 0.2273 - val_aux_output2_loss: 0.2186 - val_main_output_accuracy: 0.9326 - val_aux_output1_accuracy: 0.9248 - val_aux_output2_accuracy: 0.9291
# Epoch 26/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.4764 - main_output_loss: 0.1362 - aux_output1_loss: 0.1954 - aux_output2_loss: 0.1447 - main_output_accuracy: 0.9510 - aux_output1_accuracy: 0.9343 - aux_output2_accuracy: 0.9481 - val_loss: 0.6319 - val_main_output_loss: 0.2040 - val_aux_output1_loss: 0.2170 - val_aux_output2_loss: 0.2109 - val_main_output_accuracy: 0.9309 - val_aux_output1_accuracy: 0.9248 - val_aux_output2_accuracy: 0.9291
# Epoch 27/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.5596 - main_output_loss: 0.1714 - aux_output1_loss: 0.2104 - aux_output2_loss: 0.1778 - main_output_accuracy: 0.9396 - aux_output1_accuracy: 0.9278 - aux_output2_accuracy: 0.9374 - val_loss: 0.6210 - val_main_output_loss: 0.1909 - val_aux_output1_loss: 0.2272 - val_aux_output2_loss: 0.2028 - val_main_output_accuracy: 0.9353 - val_aux_output1_accuracy: 0.9186 - val_aux_output2_accuracy: 0.9353
# Epoch 28/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.4283 - main_output_loss: 0.1209 - aux_output1_loss: 0.1776 - aux_output2_loss: 0.1298 - main_output_accuracy: 0.9602 - aux_output1_accuracy: 0.9440 - aux_output2_accuracy: 0.9567 - val_loss: 0.5661 - val_main_output_loss: 0.1756 - val_aux_output1_loss: 0.2118 - val_aux_output2_loss: 0.1788 - val_main_output_accuracy: 0.9423 - val_aux_output1_accuracy: 0.9186 - val_aux_output2_accuracy: 0.9379
# Epoch 29/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.4141 - main_output_loss: 0.1145 - aux_output1_loss: 0.1765 - aux_output2_loss: 0.1231 - main_output_accuracy: 0.9608 - aux_output1_accuracy: 0.9387 - aux_output2_accuracy: 0.9591 - val_loss: 0.5634 - val_main_output_loss: 0.1840 - val_aux_output1_loss: 0.1960 - val_aux_output2_loss: 0.1834 - val_main_output_accuracy: 0.9335 - val_aux_output1_accuracy: 0.9265 - val_aux_output2_accuracy: 0.9335
# Epoch 30/50
# 36/36 [==============================] - 6s 158ms/step - loss: 0.3778 - main_output_loss: 0.1075 - aux_output1_loss: 0.1557 - aux_output2_loss: 0.1146 - main_output_accuracy: 0.9628 - aux_output1_accuracy: 0.9503 - aux_output2_accuracy: 0.9602 - val_loss: 0.5982 - val_main_output_loss: 0.1939 - val_aux_output1_loss: 0.2016 - val_aux_output2_loss: 0.2027 - val_main_output_accuracy: 0.9396 - val_aux_output1_accuracy: 0.9283 - val_aux_output2_accuracy: 0.9388
# Epoch 31/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.3251 - main_output_loss: 0.0858 - aux_output1_loss: 0.1429 - aux_output2_loss: 0.0964 - main_output_accuracy: 0.9715 - aux_output1_accuracy: 0.9560 - aux_output2_accuracy: 0.9698 - val_loss: 0.5958 - val_main_output_loss: 0.1991 - val_aux_output1_loss: 0.1988 - val_aux_output2_loss: 0.1979 - val_main_output_accuracy: 0.9326 - val_aux_output1_accuracy: 0.9274 - val_aux_output2_accuracy: 0.9344
# Epoch 32/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.3650 - main_output_loss: 0.1063 - aux_output1_loss: 0.1486 - aux_output2_loss: 0.1101 - main_output_accuracy: 0.9584 - aux_output1_accuracy: 0.9479 - aux_output2_accuracy: 0.9589 - val_loss: 0.8986 - val_main_output_loss: 0.3307 - val_aux_output1_loss: 0.2738 - val_aux_output2_loss: 0.2941 - val_main_output_accuracy: 0.8976 - val_aux_output1_accuracy: 0.9038 - val_aux_output2_accuracy: 0.9055
# Epoch 33/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.3999 - main_output_loss: 0.1216 - aux_output1_loss: 0.1573 - aux_output2_loss: 0.1210 - main_output_accuracy: 0.9571 - aux_output1_accuracy: 0.9475 - aux_output2_accuracy: 0.9589 - val_loss: 0.5614 - val_main_output_loss: 0.1845 - val_aux_output1_loss: 0.1940 - val_aux_output2_loss: 0.1829 - val_main_output_accuracy: 0.9265 - val_aux_output1_accuracy: 0.9274 - val_aux_output2_accuracy: 0.9283
# Epoch 34/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2427 - main_output_loss: 0.0625 - aux_output1_loss: 0.1101 - aux_output2_loss: 0.0701 - main_output_accuracy: 0.9799 - aux_output1_accuracy: 0.9650 - aux_output2_accuracy: 0.9755 - val_loss: 0.4827 - val_main_output_loss: 0.1567 - val_aux_output1_loss: 0.1684 - val_aux_output2_loss: 0.1577 - val_main_output_accuracy: 0.9449 - val_aux_output1_accuracy: 0.9423 - val_aux_output2_accuracy: 0.9475
# Epoch 35/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2084 - main_output_loss: 0.0521 - aux_output1_loss: 0.0984 - aux_output2_loss: 0.0579 - main_output_accuracy: 0.9847 - aux_output1_accuracy: 0.9720 - aux_output2_accuracy: 0.9812 - val_loss: 0.5666 - val_main_output_loss: 0.1859 - val_aux_output1_loss: 0.1866 - val_aux_output2_loss: 0.1942 - val_main_output_accuracy: 0.9431 - val_aux_output1_accuracy: 0.9335 - val_aux_output2_accuracy: 0.9466
# Epoch 36/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2976 - main_output_loss: 0.0876 - aux_output1_loss: 0.1236 - aux_output2_loss: 0.0864 - main_output_accuracy: 0.9667 - aux_output1_accuracy: 0.9591 - aux_output2_accuracy: 0.9696 - val_loss: 0.8066 - val_main_output_loss: 0.2867 - val_aux_output1_loss: 0.2434 - val_aux_output2_loss: 0.2765 - val_main_output_accuracy: 0.9081 - val_aux_output1_accuracy: 0.9055 - val_aux_output2_accuracy: 0.9108
# Epoch 37/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2513 - main_output_loss: 0.0755 - aux_output1_loss: 0.1051 - aux_output2_loss: 0.0706 - main_output_accuracy: 0.9742 - aux_output1_accuracy: 0.9672 - aux_output2_accuracy: 0.9759 - val_loss: 0.5590 - val_main_output_loss: 0.1816 - val_aux_output1_loss: 0.1912 - val_aux_output2_loss: 0.1862 - val_main_output_accuracy: 0.9414 - val_aux_output1_accuracy: 0.9291 - val_aux_output2_accuracy: 0.9344
# Epoch 38/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2308 - main_output_loss: 0.0637 - aux_output1_loss: 0.0992 - aux_output2_loss: 0.0679 - main_output_accuracy: 0.9764 - aux_output1_accuracy: 0.9641 - aux_output2_accuracy: 0.9768 - val_loss: 0.6680 - val_main_output_loss: 0.2333 - val_aux_output1_loss: 0.1979 - val_aux_output2_loss: 0.2368 - val_main_output_accuracy: 0.9230 - val_aux_output1_accuracy: 0.9265 - val_aux_output2_accuracy: 0.9221
# Epoch 39/50
# 36/36 [==============================] - 6s 159ms/step - loss: 0.2299 - main_output_loss: 0.0598 - aux_output1_loss: 0.1038 - aux_output2_loss: 0.0664 - main_output_accuracy: 0.9786 - aux_output1_accuracy: 0.9659 - aux_output2_accuracy: 0.9759 - val_loss: 0.6632 - val_main_output_loss: 0.2358 - val_aux_output1_loss: 0.2006 - val_aux_output2_loss: 0.2268 - val_main_output_accuracy: 0.9361 - val_aux_output1_accuracy: 0.9239 - val_aux_output2_accuracy: 0.9370

# %%
plot_history(model, "Google Net")

# %%
result = model.evaluate(dataset_train, verbose=0)
if len(model.metrics_names) > 2:
    test_loss_idx = model.metrics_names.index('main_output_loss')
    test_accuracy_idx = model.metrics_names.index('main_output_accuracy')
    train_loss, train_acc = result[test_loss_idx], result[test_accuracy_idx]
else:
    train_loss, train_acc = result

print('The train accuracy is:', round(train_acc, 3))

result = model.evaluate(dataset_test, verbose=0)
if len(model.metrics_names) > 2:
    test_loss_idx = model.metrics_names.index('main_output_loss')
    test_accuracy_idx = model.metrics_names.index('main_output_accuracy')
    test_loss, test_acc = result[test_loss_idx], result[test_accuracy_idx]
else:
    test_loss, test_acc = result

print('The test accuracy is:', round(test_acc, 3))
# Out:
# The train accuracy is: 0.98
# The test accuracy is: 0.925

# %%
y_prob = model.predict(X_test, verbose=0)[1]
y_pred = np.argmax(y_prob, axis=-1)
f1_scores = f1_score(y_test.ravel(), y_pred.ravel(), average=None)

# plot f1 score
plot_f1_score("GoogleNet", f1_scores)
# plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
model_results.append(save_accuarcy("GoogleNet",train_loss, train_acc, test_loss, test_acc, f1_scores))
# Out:
# Model Name: GoogleNet

# %% [markdown]
# # Create own model

# %%
def Residual(X, num_channels, strides=1, use_1x1conv=False):
    A = Conv2D(num_channels, kernel_size=3, padding='same', strides=strides)(X)
    A = BatchNormalization()(A)
    A = Activation('relu')(A)
    A = Conv2D(num_channels, kernel_size=3, padding='same')(A)
    A = BatchNormalization()(A)
    if use_1x1conv:
        X = Conv2D(num_channels, kernel_size=1, strides=strides)(X)
    A = Add()([A, X]) # Skip connection
    return relu(A)

# %%
def cs109bNet(input_shape):
    inp = Input(shape=input_shape)

    # Now it's your time!
    # Solution key

    X = Conv2D(96, kernel_size=6, strides=2, padding='same')(inp)
    X = BatchNormalization()(X)
    # X = Residual(X, 128, use_1x1conv=True, strides=2)
    X = Conv2D(64, kernel_size=1, strides=2, activation='relu', padding='same')(X)
    X = Conv2D(64, kernel_size=3, strides=2, activation='relu', padding='same')(X)
    X = inception_block(X, [64, 96, 128, 16, 32, 32])
    X = inception_block(X, [64, 96, 128, 16, 32, 32])
    X1 = auxiliary_block(X, aux_name = 'aux_output1')
    X = GlobalAvgPool2D()(X)
    X = Dense(4, activation='softmax', name = 'main_output')(X)
    model = Model(inputs=inp, outputs=[X, X1])
    return model

# %%
input_shape = (IMAGE_SIZE,IMAGE_SIZE,3)
model = cs109bNet(input_shape)

# plot model architecture
keras.utils.plot_model(model, show_shapes=True)

# compile model
model.compile(optimizer= tf.keras.optimizers.Adam(learning_rate = 0.0001),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])
print(model.summary())
# fit model
history = model.fit(dataset_train, epochs=50, batch_size=256,
                   validation_data = dataset_val, callbacks=[EarlyStopping(monitor='val_loss', patience=5)])
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_7 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 96)   10464       ['input_7[0][0]']
#
#  batch_normalization (BatchNorm  (None, 64, 64, 96)  384         ['conv2d_61[0][0]']
#  alization)
#
#  conv2d_62 (Conv2D)             (None, 32, 32, 64)   6208        ['batch_normalization[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 16, 16, 64)   36928       ['conv2d_62[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 16, 16, 96)   6240        ['conv2d_63[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 16, 16, 16)   1040        ['conv2d_63[0][0]']
#
#  max_pooling2d_15 (MaxPooling2D  (None, 16, 16, 64)  0           ['conv2d_63[0][0]']
#  )
#
#  conv2d_64 (Conv2D)             (None, 16, 16, 64)   4160        ['conv2d_63[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 16, 16, 128)  110720      ['conv2d_65[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 16, 16, 32)   12832       ['conv2d_67[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 16, 16, 32)   2080        ['max_pooling2d_15[0][0]']
#
#  concatenate_9 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_64[0][0]',
#                                                                   'conv2d_66[0][0]',
#                                                                   'conv2d_68[0][0]',
#                                                                   'conv2d_69[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 16, 16, 96)   24672       ['concatenate_9[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 16, 16, 16)   4112        ['concatenate_9[0][0]']
#
#  max_pooling2d_16 (MaxPooling2D  (None, 16, 16, 256)  0          ['concatenate_9[0][0]']
#  )
#
#  conv2d_70 (Conv2D)             (None, 16, 16, 64)   16448       ['concatenate_9[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 16, 16, 128)  110720      ['conv2d_71[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 16, 16, 32)   12832       ['conv2d_73[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 16, 16, 32)   8224        ['max_pooling2d_16[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 16, 16, 256)  0           ['conv2d_70[0][0]',
#                                                                   'conv2d_72[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_75[0][0]']
#
#  average_pooling2d_2 (AveragePo  (None, 6, 6, 256)   0           ['concatenate_10[0][0]']
#  oling2D)
#
#  conv2d_76 (Conv2D)             (None, 6, 6, 128)    32896       ['average_pooling2d_2[0][0]']
#
#  flatten_5 (Flatten)            (None, 4608)         0           ['conv2d_76[0][0]']
#
#  dense_8 (Dense)                (None, 1024)         4719616     ['flatten_5[0][0]']
#
#  global_average_pooling2d_1 (Gl  (None, 256)         0           ['concatenate_10[0][0]']
#  obalAveragePooling2D)
#
#  dropout_8 (Dropout)            (None, 1024)         0           ['dense_8[0][0]']
#
#  main_output (Dense)            (None, 4)            1028        ['global_average_pooling2d_1[0][0
#                                                                  ]']
#
#  aux_output1 (Dense)            (None, 4)            4100        ['dropout_8[0][0]']
#
# ==================================================================================================
# Total params: 5,125,704
# Trainable params: 5,125,512
# Non-trainable params: 192
# __________________________________________________________________________________________________
# None
# Epoch 1/50
# 36/36 [==============================] - 12s 117ms/step - loss: 2.4035 - main_output_loss: 1.2981 - aux_output1_loss: 1.1054 - main_output_accuracy: 0.3248 - aux_output1_accuracy: 0.5104 - val_loss: 2.6731 - val_main_output_loss: 1.3641 - val_aux_output1_loss: 1.3090 - val_main_output_accuracy: 0.2905 - val_aux_output1_accuracy: 0.2983
# Epoch 2/50
# 36/36 [==============================] - 3s 79ms/step - loss: 1.9684 - main_output_loss: 1.1557 - aux_output1_loss: 0.8127 - main_output_accuracy: 0.4660 - aux_output1_accuracy: 0.6735 - val_loss: 2.5940 - val_main_output_loss: 1.3344 - val_aux_output1_loss: 1.2596 - val_main_output_accuracy: 0.3062 - val_aux_output1_accuracy: 0.3605
# Epoch 3/50
# 36/36 [==============================] - 3s 79ms/step - loss: 1.7473 - main_output_loss: 1.0622 - aux_output1_loss: 0.6850 - main_output_accuracy: 0.5592 - aux_output1_accuracy: 0.7279 - val_loss: 2.4904 - val_main_output_loss: 1.3056 - val_aux_output1_loss: 1.1848 - val_main_output_accuracy: 0.5748 - val_aux_output1_accuracy: 0.6282
# Epoch 4/50
# 36/36 [==============================] - 3s 79ms/step - loss: 1.5708 - main_output_loss: 0.9834 - aux_output1_loss: 0.5874 - main_output_accuracy: 0.6605 - aux_output1_accuracy: 0.7722 - val_loss: 2.3473 - val_main_output_loss: 1.2638 - val_aux_output1_loss: 1.0835 - val_main_output_accuracy: 0.6159 - val_aux_output1_accuracy: 0.7130
# Epoch 5/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.4238 - main_output_loss: 0.8998 - aux_output1_loss: 0.5240 - main_output_accuracy: 0.6833 - aux_output1_accuracy: 0.7943 - val_loss: 2.2168 - val_main_output_loss: 1.2127 - val_aux_output1_loss: 1.0040 - val_main_output_accuracy: 0.6334 - val_aux_output1_accuracy: 0.7603
# Epoch 6/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.3316 - main_output_loss: 0.8259 - aux_output1_loss: 0.5057 - main_output_accuracy: 0.7061 - aux_output1_accuracy: 0.7995 - val_loss: 2.1387 - val_main_output_loss: 1.1848 - val_aux_output1_loss: 0.9539 - val_main_output_accuracy: 0.5617 - val_aux_output1_accuracy: 0.7113
# Epoch 7/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.2213 - main_output_loss: 0.7774 - aux_output1_loss: 0.4439 - main_output_accuracy: 0.7102 - aux_output1_accuracy: 0.8341 - val_loss: 1.8946 - val_main_output_loss: 1.0891 - val_aux_output1_loss: 0.8055 - val_main_output_accuracy: 0.6509 - val_aux_output1_accuracy: 0.8075
# Epoch 8/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.1613 - main_output_loss: 0.7462 - aux_output1_loss: 0.4151 - main_output_accuracy: 0.7207 - aux_output1_accuracy: 0.8356 - val_loss: 1.7732 - val_main_output_loss: 1.0385 - val_aux_output1_loss: 0.7348 - val_main_output_accuracy: 0.6352 - val_aux_output1_accuracy: 0.8136
# Epoch 9/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.1149 - main_output_loss: 0.7066 - aux_output1_loss: 0.4083 - main_output_accuracy: 0.7369 - aux_output1_accuracy: 0.8404 - val_loss: 1.6529 - val_main_output_loss: 0.9632 - val_aux_output1_loss: 0.6898 - val_main_output_accuracy: 0.6264 - val_aux_output1_accuracy: 0.7944
# Epoch 10/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.0674 - main_output_loss: 0.6924 - aux_output1_loss: 0.3750 - main_output_accuracy: 0.7400 - aux_output1_accuracy: 0.8505 - val_loss: 1.5682 - val_main_output_loss: 0.9508 - val_aux_output1_loss: 0.6175 - val_main_output_accuracy: 0.6378 - val_aux_output1_accuracy: 0.8110
# Epoch 11/50
# 36/36 [==============================] - 3s 80ms/step - loss: 1.0203 - main_output_loss: 0.6698 - aux_output1_loss: 0.3505 - main_output_accuracy: 0.7466 - aux_output1_accuracy: 0.8577 - val_loss: 1.3749 - val_main_output_loss: 0.8503 - val_aux_output1_loss: 0.5246 - val_main_output_accuracy: 0.6833 - val_aux_output1_accuracy: 0.8355
# Epoch 12/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.9836 - main_output_loss: 0.6522 - aux_output1_loss: 0.3314 - main_output_accuracy: 0.7490 - aux_output1_accuracy: 0.8704 - val_loss: 1.4562 - val_main_output_loss: 0.9239 - val_aux_output1_loss: 0.5323 - val_main_output_accuracy: 0.5879 - val_aux_output1_accuracy: 0.8040
# Epoch 13/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.9817 - main_output_loss: 0.6443 - aux_output1_loss: 0.3374 - main_output_accuracy: 0.7531 - aux_output1_accuracy: 0.8674 - val_loss: 1.1941 - val_main_output_loss: 0.7772 - val_aux_output1_loss: 0.4169 - val_main_output_accuracy: 0.6877 - val_aux_output1_accuracy: 0.8390
# Epoch 14/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.9083 - main_output_loss: 0.6194 - aux_output1_loss: 0.2890 - main_output_accuracy: 0.7643 - aux_output1_accuracy: 0.8921 - val_loss: 1.0873 - val_main_output_loss: 0.6983 - val_aux_output1_loss: 0.3889 - val_main_output_accuracy: 0.7419 - val_aux_output1_accuracy: 0.8626
# Epoch 15/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.9061 - main_output_loss: 0.6165 - aux_output1_loss: 0.2896 - main_output_accuracy: 0.7649 - aux_output1_accuracy: 0.8932 - val_loss: 1.1258 - val_main_output_loss: 0.7358 - val_aux_output1_loss: 0.3900 - val_main_output_accuracy: 0.6885 - val_aux_output1_accuracy: 0.8583
# Epoch 16/50
# 36/36 [==============================] - 3s 79ms/step - loss: 0.8672 - main_output_loss: 0.6109 - aux_output1_loss: 0.2562 - main_output_accuracy: 0.7643 - aux_output1_accuracy: 0.9026 - val_loss: 1.1772 - val_main_output_loss: 0.7942 - val_aux_output1_loss: 0.3830 - val_main_output_accuracy: 0.6457 - val_aux_output1_accuracy: 0.8443
# Epoch 17/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.8507 - main_output_loss: 0.6009 - aux_output1_loss: 0.2498 - main_output_accuracy: 0.7632 - aux_output1_accuracy: 0.9015 - val_loss: 0.8909 - val_main_output_loss: 0.5976 - val_aux_output1_loss: 0.2933 - val_main_output_accuracy: 0.7612 - val_aux_output1_accuracy: 0.9003
# Epoch 18/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.8366 - main_output_loss: 0.5962 - aux_output1_loss: 0.2404 - main_output_accuracy: 0.7726 - aux_output1_accuracy: 0.9087 - val_loss: 0.9343 - val_main_output_loss: 0.6392 - val_aux_output1_loss: 0.2950 - val_main_output_accuracy: 0.7262 - val_aux_output1_accuracy: 0.8819
# Epoch 19/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.8089 - main_output_loss: 0.5795 - aux_output1_loss: 0.2293 - main_output_accuracy: 0.7768 - aux_output1_accuracy: 0.9111 - val_loss: 0.9230 - val_main_output_loss: 0.6133 - val_aux_output1_loss: 0.3097 - val_main_output_accuracy: 0.7393 - val_aux_output1_accuracy: 0.8670
# Epoch 20/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.8000 - main_output_loss: 0.5769 - aux_output1_loss: 0.2231 - main_output_accuracy: 0.7702 - aux_output1_accuracy: 0.9146 - val_loss: 0.8397 - val_main_output_loss: 0.5682 - val_aux_output1_loss: 0.2716 - val_main_output_accuracy: 0.7927 - val_aux_output1_accuracy: 0.8950
# Epoch 21/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7776 - main_output_loss: 0.5585 - aux_output1_loss: 0.2192 - main_output_accuracy: 0.7842 - aux_output1_accuracy: 0.9208 - val_loss: 0.8236 - val_main_output_loss: 0.5477 - val_aux_output1_loss: 0.2759 - val_main_output_accuracy: 0.7813 - val_aux_output1_accuracy: 0.8906
# Epoch 22/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7748 - main_output_loss: 0.5584 - aux_output1_loss: 0.2164 - main_output_accuracy: 0.7798 - aux_output1_accuracy: 0.9212 - val_loss: 0.8033 - val_main_output_loss: 0.5549 - val_aux_output1_loss: 0.2484 - val_main_output_accuracy: 0.7752 - val_aux_output1_accuracy: 0.9046
# Epoch 23/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7277 - main_output_loss: 0.5345 - aux_output1_loss: 0.1932 - main_output_accuracy: 0.7969 - aux_output1_accuracy: 0.9256 - val_loss: 0.8388 - val_main_output_loss: 0.5677 - val_aux_output1_loss: 0.2711 - val_main_output_accuracy: 0.7883 - val_aux_output1_accuracy: 0.8994
# Epoch 24/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7100 - main_output_loss: 0.5279 - aux_output1_loss: 0.1820 - main_output_accuracy: 0.7958 - aux_output1_accuracy: 0.9304 - val_loss: 0.7931 - val_main_output_loss: 0.5230 - val_aux_output1_loss: 0.2702 - val_main_output_accuracy: 0.7988 - val_aux_output1_accuracy: 0.9003
# Epoch 25/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7061 - main_output_loss: 0.5209 - aux_output1_loss: 0.1852 - main_output_accuracy: 0.8004 - aux_output1_accuracy: 0.9311 - val_loss: 0.7718 - val_main_output_loss: 0.5375 - val_aux_output1_loss: 0.2342 - val_main_output_accuracy: 0.7839 - val_aux_output1_accuracy: 0.9081
# Epoch 26/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.6746 - main_output_loss: 0.5181 - aux_output1_loss: 0.1565 - main_output_accuracy: 0.7997 - aux_output1_accuracy: 0.9446 - val_loss: 0.7737 - val_main_output_loss: 0.5104 - val_aux_output1_loss: 0.2633 - val_main_output_accuracy: 0.8058 - val_aux_output1_accuracy: 0.8994
# Epoch 27/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.7040 - main_output_loss: 0.5350 - aux_output1_loss: 0.1691 - main_output_accuracy: 0.7934 - aux_output1_accuracy: 0.9429 - val_loss: 0.7600 - val_main_output_loss: 0.5090 - val_aux_output1_loss: 0.2510 - val_main_output_accuracy: 0.7909 - val_aux_output1_accuracy: 0.9020
# Epoch 28/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.6544 - main_output_loss: 0.5069 - aux_output1_loss: 0.1476 - main_output_accuracy: 0.8056 - aux_output1_accuracy: 0.9448 - val_loss: 0.7265 - val_main_output_loss: 0.4935 - val_aux_output1_loss: 0.2330 - val_main_output_accuracy: 0.8014 - val_aux_output1_accuracy: 0.9160
# Epoch 29/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.6438 - main_output_loss: 0.4994 - aux_output1_loss: 0.1443 - main_output_accuracy: 0.8081 - aux_output1_accuracy: 0.9481 - val_loss: 0.7080 - val_main_output_loss: 0.4885 - val_aux_output1_loss: 0.2195 - val_main_output_accuracy: 0.8189 - val_aux_output1_accuracy: 0.9204
# Epoch 30/50
# 36/36 [==============================] - 3s 79ms/step - loss: 0.6271 - main_output_loss: 0.4912 - aux_output1_loss: 0.1360 - main_output_accuracy: 0.8137 - aux_output1_accuracy: 0.9501 - val_loss: 0.6878 - val_main_output_loss: 0.4724 - val_aux_output1_loss: 0.2154 - val_main_output_accuracy: 0.8189 - val_aux_output1_accuracy: 0.9169
# Epoch 31/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.6088 - main_output_loss: 0.4824 - aux_output1_loss: 0.1263 - main_output_accuracy: 0.8148 - aux_output1_accuracy: 0.9547 - val_loss: 0.7036 - val_main_output_loss: 0.4921 - val_aux_output1_loss: 0.2116 - val_main_output_accuracy: 0.8145 - val_aux_output1_accuracy: 0.9204
# Epoch 32/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.5996 - main_output_loss: 0.4737 - aux_output1_loss: 0.1259 - main_output_accuracy: 0.8197 - aux_output1_accuracy: 0.9578 - val_loss: 0.8087 - val_main_output_loss: 0.5263 - val_aux_output1_loss: 0.2825 - val_main_output_accuracy: 0.8119 - val_aux_output1_accuracy: 0.8889
# Epoch 33/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.6547 - main_output_loss: 0.5219 - aux_output1_loss: 0.1328 - main_output_accuracy: 0.8004 - aux_output1_accuracy: 0.9514 - val_loss: 0.6891 - val_main_output_loss: 0.4783 - val_aux_output1_loss: 0.2109 - val_main_output_accuracy: 0.8329 - val_aux_output1_accuracy: 0.9230
# Epoch 34/50
# 36/36 [==============================] - 3s 79ms/step - loss: 0.6215 - main_output_loss: 0.4970 - aux_output1_loss: 0.1245 - main_output_accuracy: 0.8111 - aux_output1_accuracy: 0.9569 - val_loss: 0.7636 - val_main_output_loss: 0.5430 - val_aux_output1_loss: 0.2206 - val_main_output_accuracy: 0.7743 - val_aux_output1_accuracy: 0.9195
# Epoch 35/50
# 36/36 [==============================] - 3s 80ms/step - loss: 0.5911 - main_output_loss: 0.4716 - aux_output1_loss: 0.1195 - main_output_accuracy: 0.8212 - aux_output1_accuracy: 0.9549 - val_loss: 0.7547 - val_main_output_loss: 0.5335 - val_aux_output1_loss: 0.2212 - val_main_output_accuracy: 0.7620 - val_aux_output1_accuracy: 0.9143

# %%
plot_history(model, "Self Built Model2")

# %%
result = model.evaluate(dataset_train, verbose=0)
if len(model.metrics_names) > 2:
    test_loss_idx = model.metrics_names.index('main_output_loss')
    test_accuracy_idx = model.metrics_names.index('main_output_accuracy')
    train_loss, train_acc = result[test_loss_idx], result[test_accuracy_idx]
else:
    train_loss, train_acc = result

print('The train accuracy is:', round(train_acc, 3))

result = model.evaluate(dataset_test, verbose=0)
if len(model.metrics_names) > 2:
    test_loss_idx = model.metrics_names.index('main_output_loss')
    test_accuracy_idx = model.metrics_names.index('main_output_accuracy')
    test_loss, test_acc = result[test_loss_idx], result[test_accuracy_idx]
else:
    test_loss, test_acc = result

print('The test accuracy is:', round(test_acc, 3))
# Out:
# The train accuracy is: 0.766
# The test accuracy is: 0.761

# %%
y_prob = model.predict(X_test, verbose=0)[1]
y_pred = np.argmax(y_prob, axis=-1)
f1_scores = f1_score(y_test.ravel(), y_pred.ravel(), average=None)

# plot f1 score
plot_f1_score("Self Built Model2", f1_scores)
# plot confusion matrix
plot_confusion_matrix(y_test, y_pred)

# %%
model_results.append(save_accuarcy("Self Built Model2",train_loss, train_acc, test_loss, test_acc, f1_scores))
# Out:
# Model Name: Self Built Model2

# %%
result_table = pd.DataFrame(model_results)
result_table
# Out:
#                 Name  Train Accuracy  Train Loss  Test Accuracy  Test Loss  \
# 0  Self Built Model1        0.999781    0.006539       0.939741   0.231824
# 1             Vgg 16        0.998687    0.006517       0.967201   0.111469
# 2           ResNet50        0.719195    0.928754       0.697941   1.190944
# 3          GoogleNet        0.980302    0.057669       0.925248   0.287545
# 4  Self Built Model2        0.766251    0.515401       0.761251   0.592253
#
#                                                   f1
# 0  [0.9272419627749577, 0.8716216216216216, 0.976...
# 1  [0.9509803921568627, 0.9333333333333332, 0.991...
# 2  [0.6856465005931198, 0.22598870056497175, 0.84...
# 3  [0.9116607773851589, 0.8581196581196581, 0.980...
# 4  [0.8932038834951457, 0.8424657534246576, 0.971...

# %%
result_table = pd.concat([result_table.iloc[:1], result_table.iloc[1:4]]).reset_index(drop = True)
result_table["Name"][0] = "Self Built Model"
result_table["Name"][1] = "VGG16"
result_table
# Out:
#                Name  Train Accuracy  Train Loss  Test Accuracy  Test Loss  \
# 0  Self Built Model        0.999781    0.006539       0.939741   0.231824
# 1             VGG16        0.998687    0.006517       0.967201   0.111469
# 2          ResNet50        0.719195    0.928754       0.697941   1.190944
# 3         GoogleNet        0.980302    0.057669       0.925248   0.287545
#
#                                                   f1
# 0  [0.9272419627749577, 0.8716216216216216, 0.976...
# 1  [0.9509803921568627, 0.9333333333333332, 0.991...
# 2  [0.6856465005931198, 0.22598870056497175, 0.84...
# 3  [0.9116607773851589, 0.8581196581196581, 0.980...

# %%
model_results
# Out:
# [{'Name': 'Self Built Model1',
#   'Train Accuracy': 0.9997811317443848,
#   'Train Loss': 0.006539199501276016,
#   'Test Accuracy': 0.9397406578063965,
#   'Test Loss': 0.23182423412799835,
#   'f1': array([0.92724196, 0.87162162, 0.97691373, 0.96753247])},
#  {'Name': 'Vgg 16',
#   'Train Accuracy': 0.9986867904663086,
#   'Train Loss': 0.006517110392451286,
#   'Test Accuracy': 0.9672006368637085,
#   'Test Loss': 0.11146914213895798,
#   'f1': array([0.95098039, 0.93333333, 0.99134734, 0.98502496])},
#  {'Name': 'ResNet50',
#   'Train Accuracy': 0.7191945910453796,
#   'Train Loss': 0.9287540912628174,
#   'Test Accuracy': 0.6979405283927917,
#   'Test Loss': 1.1909440755844116,
#   'f1': array([0.6856465 , 0.2259887 , 0.84665227, 0.77755511])},
#  {'Name': 'GoogleNet',
#   'Train Accuracy': 0.9803020358085632,
#   'Train Loss': 0.057668931782245636,
#   'Test Accuracy': 0.9252479076385498,
#   'Test Loss': 0.28754502534866333,
#   'f1': array([0.91166078, 0.85811966, 0.9804401 , 0.91577335])},
#  {'Name': 'Self Built Model2',
#   'Train Accuracy': 0.7662508487701416,
#   'Train Loss': 0.5154006481170654,
#   'Test Accuracy': 0.7612509727478027,
#   'Test Loss': 0.5922529101371765,
#   'f1': array([0.89320388, 0.84246575, 0.97177914, 0.96528926])}]

# %%
x_labels = result_table['Name']

# Create the bar plot
width = 0.3
plt.figure(figsize=(8, 6))
plt.bar(np.arange(4), result_table['Train Accuracy'], width, align = "center", alpha = 0.5,  label='Train Accuracy')
for i in range(4):
  plt.text(i, result_table['Train Accuracy'][i]/2.5, str(np.round(result_table['Train Accuracy'][i], 3))+'\n',
              ha='center', va='bottom', color='white', weight='bold', fontsize = 9)
plt.bar(np.arange(4) + width, result_table['Test Accuracy'], width, align = "center", alpha = 0.7, label='Test Accuracy')
for i in range(4):
  plt.text(i + width, result_table['Test Accuracy'][i]/3, str(np.round(result_table['Test Accuracy'][i], 3))+'\n',
              ha='center', va='bottom', color='steelblue', weight='bold', fontsize = 9)
plt.legend(loc='upper right')
plt.xticks(np.arange(4), x_labels, rotation=45, ha='right')
plt.xlabel('Model')
plt.ylabel('Accuracy')
plt.tight_layout()

# %%
x_labels = result_table['Name']

# Create the bar plot
width = 0
plt.figure(figsize=(16, 6))
for i in range(4):
  plt.bar(np.arange(4) + width, result_table['f1'][i], 0.2, align = "center", alpha = 0.5,  label=x_labels[i])
  for j in range(4):
    plt.text(j + width, result_table['f1'][i][j]/2.5, str(np.round(result_table['f1'][i][j], 3))+'\n',
                ha='center', va='bottom', color='white', weight='bold', fontsize = 9)
  width += 0.2

plt.legend(loc='upper right')
plt.xticks(np.arange(4), labels, rotation=45, ha='right')
plt.xlabel('Brain Tumor Types')
plt.ylabel('F1 Score')

plt.tight_layout()
